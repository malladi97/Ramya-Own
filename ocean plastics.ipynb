# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

df = pd.read_excel('C:/Users/ramya/Desktop/plastic_dataset.xlsx',sheetname='Sheet1')
print(df.head(5))
# Out:
# C:\Users\ramya\Anaconda3\lib\site-packages\pandas\util\_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#                   Date  Latitude  Longitude  CD1  (/km^2)  CD2  (/km^2)  \
# 0                  NaN       NaN        NaN  .335-.999 mm  1.00-4.75 mm
# 1  2010-09-01 00:00:00   19.9432   -64.5649         58103       21259.9
# 2  2010-09-01 00:00:00   20.2173   -64.3828       6639.79        4031.3
# 3  2010-09-01 00:00:00   20.4521   -64.1968       15246.7       12147.8
# 4  2010-10-01 00:00:00   21.1293   -63.8333       5347.35       6851.29
#
#   CD3  (/km^2) CD4  (/km^2)  WD1 (g/km^2)  WD2 (g/km^2) WD3 (g/km^2)  \
# 0  4.75-200 mm      >200 mm  .335-.999 mm  1.00-4.75 mm  4.75-200 mm
# 1      2226.17          NaN          4.45         26.83         4.23
# 2      1067.11          NaN          1.04         28.69        40.79
# 3       991.66          NaN          2.57         42.62      3503.27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1572 entries, 0 to 1571
# Data columns (total 16 columns):
# Date            1571 non-null object
# Latitude        1571 non-null float64
# Longitude       1571 non-null float64
# CD1  (/km^2)    680 non-null object
# CD2  (/km^2)    680 non-null object
# CD3  (/km^2)    808 non-null object
# CD4  (/km^2)    1090 non-null object
# WD1 (g/km^2)    442 non-null object
# WD2 (g/km^2)    442 non-null object
# WD3 (g/km^2)    570 non-null object
# WD4 (g/km^2)    888 non-null object
# Sea State       1214 non-null object
# Source          1571 non-null object
# Info            1571 non-null object
# Comments        37 non-null object
# Unnamed         377 non-null object
# dtypes: float64(2), object(14)
# memory usage: 110.6+ KB

# %%
import seaborn as sns
import pandas as pd
missing_values = df.isnull().sum().sort_values(ascending = False)
percent_missing =(df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([missing_values,percent_missing], axis=1 ,keys=['missing_values','percent_missing'])
missing_data.head(10)
# Out:
#               missing_values  percent_missing
# Comments                1535         0.976463
# Unnamed                 1195         0.760178
# WD2 (g/km^2)            1130         0.718830
# WD1 (g/km^2)            1130         0.718830
# WD3 (g/km^2)            1002         0.637405
# CD2  (/km^2)             892         0.567430
# CD1  (/km^2)             892         0.567430
# CD3  (/km^2)             764         0.486005
# WD4 (g/km^2)             684         0.435115
# CD4  (/km^2)             482         0.306616

# %%
df.fillna(method = 'ffill',inplace=True)

# %%
df.head(40)
# Out:
#                    Date  Latitude  Longitude  CD1  (/km^2)  CD2  (/km^2)  \
# 0                   NaN       NaN        NaN  .335-.999 mm  1.00-4.75 mm
# 1   2010-09-01 00:00:00   19.9432   -64.5649         58103       21259.9
# 2   2010-09-01 00:00:00   20.2173   -64.3828       6639.79        4031.3
# 3   2010-09-01 00:00:00   20.4521   -64.1968       15246.7       12147.8
# 4   2010-10-01 00:00:00   21.1293   -63.8333       5347.35       6851.29
# 5   2010-10-01 00:00:00   21.4730   -63.5899       4090.58       5317.76
# 6   2010-10-01 00:00:00   21.7367   -63.4227       44914.6       46144.8
# 7   2010-11-01 00:00:00   22.1500   -63.1474       17324.8       4519.52
# 8   2010-11-01 00:00:00   22.8418   -62.7592       10467.5       10329.8
# 9   2010-12-01 00:00:00   24.3576   -62.8129       7434.53       9436.14
# 10  2010-12-01 00:00:00   24.3576   -62.8129             0       1510.37
# 11           13/01/2010   24.7657   -62.7221        377.59       1636.23
# ...

# %%
import seaborn as sns
import pandas as pd
missing_values = df.isnull().sum().sort_values(ascending = False)
percent_missing =(df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([missing_values,percent_missing], axis=1 ,keys=['missing_values','percent_missing'])
missing_data.head(10)
# Out:
#               missing_values  percent_missing
# Unnamed                  821         0.522265
# Comments                  35         0.022265
# Info                       1         0.000636
# Source                     1         0.000636
# Longitude                  1         0.000636
# Latitude                   1         0.000636
# Date                       1         0.000636
# Sea State                  0         0.000000
# WD4 (g/km^2)               0         0.000000
# WD3 (g/km^2)               0         0.000000

# %%
import pandas as pd
import folium

# %%
from IPython.display import display
from folium import features
map1 = folium.Map(Location = [19.9432,-64.5649],zoom_start=10)
maploc= features.Marker([19.9432,-64.5649])
icon1= features.Icon(color='blue')
maploc.add_child(icon1)
map1.add_child(maploc)
map1.save('index.html')
display(map1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
from pandas import *
df['Location']=tuple(zip(*df[['Latitude','Longitude']].values.T))
df
# Out:
#                      Date  Latitude  Longitude  CD1  (/km^2)  CD2  (/km^2)  \
# 0                     NaN       NaN        NaN  .335-.999 mm  1.00-4.75 mm
# 1     2010-09-01 00:00:00  19.94320  -64.56490         58103       21259.9
# 2     2010-09-01 00:00:00  20.21730  -64.38280       6639.79        4031.3
# 3     2010-09-01 00:00:00  20.45210  -64.19680       15246.7       12147.8
# 4     2010-10-01 00:00:00  21.12930  -63.83330       5347.35       6851.29
# 5     2010-10-01 00:00:00  21.47300  -63.58990       4090.58       5317.76
# 6     2010-10-01 00:00:00  21.73670  -63.42270       44914.6       46144.8
# 7     2010-11-01 00:00:00  22.15000  -63.14740       17324.8       4519.52
# 8     2010-11-01 00:00:00  22.84180  -62.75920       10467.5       10329.8
# 9     2010-12-01 00:00:00  24.35760  -62.81290       7434.53       9436.14
# 10    2010-12-01 00:00:00  24.35760  -62.81290             0       1510.37
# ...

# %%
del df['Unnamed']

# %%
df.dropna()
# Out:
#                      Date  Latitude  Longitude CD1  (/km^2) CD2  (/km^2)  \
# 35    2010-09-02 00:00:00  36.29370  -33.38880      1163.54      19198.5
# 12             13/01/2010  25.37510  -62.47850      3126.56      2918.12
# ...

# %%
print(df['Location'])
# Out:
# 0                (nan, nan)
# 1       (19.9432, -64.5649)
# 2       (20.2173, -64.3828)
# 3       (20.4521, -64.1968)
# 4       (21.1293, -63.8333)
# 5        (21.473, -63.5899)
# 6       (21.7367, -63.4227)
# 7         (22.15, -63.1474)
# 8       (22.8418, -62.7592)
# 9       (24.3576, -62.8129)
# 10      (24.3576, -62.8129)
# 11      (24.7657, -62.7221)
# 12      (25.3751, -62.4785)
# 13      (25.5607, -62.4387)
# 14      (26.0914, -61.7168)
# 15       (29.249, -62.9857)
# 16      (29.7453, -63.2167)
# 17      (30.5477, -63.7064)
# 18      (31.1813, -64.0147)
# 19       (31.535, -64.2677)
# 20      (31.9644, -64.5448)
# 21        (32.32, -64.4322)
# 22       (32.079, -64.6316)
# 23      (31.5865, -62.7727)
# 24      (31.2001, -62.0368)
# 25      (30.8735, -61.3126)
# 26       (30.073, -58.7081)
# 27       (30.073, -58.7081)
# 28      (29.6835, -56.6993)
# 29      (29.5392, -54.9628)
#                ...
# 1542     (16.0355, 87.8699)
# 1543     (15.8782, 88.2682)
# ...

# %%
Loclist=df.Location.values.tolist()
Loclist
# Out:
# [(nan, nan),
#  (19.9432, -64.5649),
#  (20.2173, -64.3828),
#  (20.4521, -64.1968),
#  (21.1293, -63.8333),
#  (21.473, -63.5899),
#  (21.7367, -63.4227),
#  (22.15, -63.1474),
#  (22.8418, -62.7592),
#  (24.3576, -62.8129),
#  (24.3576, -62.8129),
#  (24.7657, -62.7221),
#  (25.3751, -62.4785),
#  (25.5607, -62.4387),
#  (26.0914, -61.7168),
#  (29.249, -62.9857),
#  (29.7453, -63.2167),
#  (30.5477, -63.7064),
#  (31.1813, -64.0147),
#  (31.535, -64.2677),
#  (31.9644, -64.5448),
#  (32.32, -64.4322),
#  (32.079, -64.6316),
#  (31.5865, -62.7727),
#  (31.2001, -62.0368),
#  (30.8735, -61.3126),
#  (30.073, -58.7081),
#  (30.073, -58.7081),
#  (29.6835, -56.6993),
#  (29.5392, -54.9628),
#  (29.2797, -53.6117),
#  (28.907, -51.8931),
#  (28.7729, -51.0777),
#  (28.5522, -50.1026),
#  (35.6729, -35.0237),
#  (36.2937, -33.3888),
#  (-23.4996, -39.2757),
#  (-23.729, -37.4867),
#  (-23.8868, -36.6933),
#  (-24.1104, -33.9573),
#  (-23.0308, -30.8532),
#  (-22.297, -29.2472),
# ...

# %%
len(Loclist)
Loclist[5]
# Out:
# (21.473, -63.5899)

# %%
map=folium.Map(location=Loclist[5],zoom_start=10)
for i in range(1,len(Loclist)):
    folium.Marker(Loclist[i]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
